# %% [markdown]
# # 📘 Comprehensive Natural Language Processing (NLP) Notes
#
# A complete end-to-end guide with theory + practical Python examples.

# %% [markdown]
# ## 1. Introduction to NLP
#
# Natural Language Processing (NLP) is a field of AI that enables computers to understand, interpret, and generate human language.
#
# Applications:
# - Chatbots
# - Sentiment Analysis
# - Machine Translation
# - Speech Recognition
# - Search Engines

# %% [markdown]
# ## 2. NLP Pipeline
#
# 1. Text Collection
# 2. Text Preprocessing
# 3. Feature Engineering
# 4. Modeling
# 5. Evaluation
# 6. Deployment

# %% [markdown]
# ## 3. Text Preprocessing
#
# Includes:
# - Tokenization
# - Lowercasing
# - Removing punctuation
# - Stopword removal
# - Stemming
# - Lemmatization

# %% [markdown]
# ## 4. Tokenization Example

# %% [markdown]
# ## 5. Stopword Removal

# %% [markdown]
# ## 6. Stemming vs Lemmatization

# %% [markdown]
# ## 7. Text Representation
#
# Methods:
# - Bag of Words
# - TF-IDF
# - Word Embeddings (Word2Vec, GloVe)

# %% [markdown]
# ## 8. Bag of Words Example

# %% [markdown]
# ## 9. TF-IDF Example

# %% [markdown]
# ## 10. Word Embeddings
#
# Dense vector representations of words capturing semantic meaning.

# %% [markdown]
# ## 11. Machine Learning in NLP
#
# Algorithms:
# - Naive Bayes
# - Logistic Regression
# - SVM
# - Decision Trees

# %% [markdown]
# ## 12. Deep Learning in NLP
#
# Neural Networks:
# - RNN
# - LSTM
# - GRU
# - Transformers

# %% [markdown]
# ## 13. Sentiment Analysis

# %% [markdown]
# ## 14. Named Entity Recognition (NER)

# %% [markdown]
# ## 15. Part-of-Speech Tagging

# %% [markdown]
# ## 16. Topic Modeling
#
# Using LDA to discover topics.

# %% [markdown]
# ## 17. Transformers
#
# Attention-based models that revolutionized NLP.

# %% [markdown]
# ## 18. BERT
#
# Bidirectional Encoder Representations from Transformers.

# %% [markdown]
# ## 19. GPT
#
# Generative Pre-trained Transformer models for text generation.

# %% [markdown]
# ## 20. Evaluation Metrics
#
# Accuracy, Precision, Recall, F1-score

# %% [markdown]
# ## 21. Deployment
#
# Deploy NLP models using APIs, Streamlit, Flask.

# %% [markdown]
# ## 22. End-to-End Project
#
# Build a sentiment analysis model.

# %%
# Tokenization Example
from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()
tokens = tokenizer.tokenize("NLP is amazing!")

tokens
# Out:
# ['NLP', 'is', 'amazing', '!']

# %%
# Stopword Removal
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))
filtered = [w for w in tokens if w.lower() not in stop_words]
filtered
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['NLP', 'amazing', '!']

# %%
# Stemming
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
[stemmer.stem(word) for word in tokens]
# Out:
# ['nlp', 'is', 'amaz', '!']

# %%
# Lemmatization
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()
[lemmatizer.lemmatize(word) for word in tokens]
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['NLP', 'is', 'amazing', '!']

# %%
# Bag of Words
from sklearn.feature_extraction.text import CountVectorizer

docs = ["I love NLP", "NLP is fun"]
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(docs)
vectorizer.get_feature_names_out(), X.toarray()
# Out:
# (array(['fun', 'is', 'love', 'nlp'], dtype=object),
#  array([[0, 0, 1, 1],
#         [1, 1, 0, 1]]))

# %%
# TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
X = tfidf.fit_transform(docs)
tfidf.get_feature_names_out(), X.toarray()
# Out:
# (array(['fun', 'is', 'love', 'nlp'], dtype=object),
#  array([[0.        , 0.        , 0.81480247, 0.57973867],
#         [0.6316672 , 0.6316672 , 0.        , 0.44943642]]))

# %%
# Simple Sentiment Analysis
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

texts = ["I love this", "I hate this"]
labels = [1, 0]

vec = CountVectorizer()
X = vec.fit_transform(texts)

model = LogisticRegression()
model.fit(X, labels)

model.predict(vec.transform(["I love NLP"]))
# Out:
# array([1])
