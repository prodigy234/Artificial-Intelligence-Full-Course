# %% [markdown]
# # Mastering Pandas for Data Analysis: A Comprehensive Guide

# %% [markdown]
# # What is Pandas?
#
# Pandas is a powerful open-source Python library used for data manipulation, data cleaning, and data analysis.
#
# Built on top of NumPy, it allows for fast operations on tabular data (data in tables), like spreadsheets or SQL tables.

# %% [markdown]
# ## Pandas Core Data Structures
#
# ### 1. Series
#
# A one-dimensional labeled array capable of holding any data type.

# %%
import pandas as pd

s = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %% [markdown]
# ### Key Features:
#
# - Automatically assigns labels (indices) unless specified.
#
# - Can hold any data type (int, float, str, etc.)

# %% [markdown]
# ### 2. DataFrame
#
# A two-dimensional labeled data structure (like a table in Excel or a database).

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['Lagos', 'Abuja', 'Ibadan']
}
dfs = pd.DataFrame(data)
print(dfs)
# Out:
#       Name  Age    City
# 0    Alice   25   Lagos
# 1      Bob   30   Abuja
# 2  Charlie   35  Ibadan

# %% [markdown]
# ### Key Features:
#
# - Think of it like a dictionary of Series.
#
# - Labeled rows (index) and columns.

# %% [markdown]
# ## Creating DataFrames

# %%
# From a dictionary:

pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
# From a list of lists:

pd.DataFrame([[1, 2], [3, 4]], columns=['A', 'B'])
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
# From a CSV file:

df = pd.read_csv('sales.csv')

# %% [markdown]
# ## DataFrame Basic Operations

# %%
df.head()  # first 5 rows
# Out:
#    sale_id  product_id  employee_id   sale_date  quantity_sold  total_price
# 0        1           3            2  2023-03-01              3         1993
# 1        2           4            2  2023-03-11              9          912
# 2        3           4            3  2023-03-21              3          940
# 3        4           1            1  2023-03-31              5          963
# 4        5           1            2  2023-04-10              8          490

# %%
df.tail()  # last 5 rows
# Out:
#     sale_id  product_id  employee_id   sale_date  quantity_sold  total_price
# 15       16           2            2  2023-07-29              9          221
# 16       17           3            1  2023-08-08              4         1289
# 17       18           3            5  2023-08-18              7          644
# 18       19           5            5  2023-08-28              9          728
# 19       20           4            3  2023-09-07              6         1552

# %%
df.info()   # summary info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sale_id        20 non-null     int64
#  1   product_id     20 non-null     int64
#  2   employee_id    20 non-null     int64
#  3   sale_date      20 non-null     object
#  4   quantity_sold  20 non-null     int64
#  5   total_price    20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB

# %%
df.describe()  # statistical summary
# Out:
#         sale_id  product_id  employee_id  quantity_sold  total_price
# count  20.00000   20.000000    20.000000      20.000000    20.000000
# mean   10.50000    3.200000     2.900000       5.550000   984.500000
# std     5.91608    1.361114     1.333772       2.723678   483.480202
# min     1.00000    1.000000     1.000000       1.000000   221.000000
# 25%     5.75000    2.750000     2.000000       3.750000   698.750000
# 50%    10.50000    3.500000     2.500000       5.500000   926.000000
# 75%    15.25000    4.000000     4.000000       7.250000  1297.000000
# max    20.00000    5.000000     5.000000       9.000000  1993.000000

# %%
# 1. Viewing Data

df.head(5)      
df.tail()      
df.info()      
df.describe()  # statistical summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sale_id        20 non-null     int64
#  1   product_id     20 non-null     int64
#  2   employee_id    20 non-null     int64
#  3   sale_date      20 non-null     object
#  4   quantity_sold  20 non-null     int64
#  5   total_price    20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB
#         sale_id  product_id  employee_id  quantity_sold  total_price
# count  20.00000   20.000000    20.000000      20.000000    20.000000
# mean   10.50000    3.200000     2.900000       5.550000   984.500000
# std     5.91608    1.361114     1.333772       2.723678   483.480202
# min     1.00000    1.000000     1.000000       1.000000   221.000000
# 25%     5.75000    2.750000     2.000000       3.750000   698.750000
# 50%    10.50000    3.500000     2.500000       5.500000   926.000000
# 75%    15.25000    4.000000     4.000000       7.250000  1297.000000
# max    20.00000    5.000000     5.000000       9.000000  1993.000000

# %% [markdown]
# # 2. Accessing Columns and Rows

# %%
df['total_price']         # Access column
# Out:
# 0     1993
# 1      912
# 2      940
# 3      963
# 4      490
# 5      717
# 6      903
# 7     1094
# 8     1321
# 9     1506
# 10     332
# 11     765
# 12    1829
# 13     417
# 14    1074
# 15     221
# 16    1289
# 17     644
# 18     728
# 19    1552
# Name: total_price, dtype: int64

# %%
df[['product_id', 'quantity_sold']]  # Multiple columns
# Out:
#     product_id  quantity_sold
# 0            3              3
# 1            4              9
# 2            4              3
# 3            1              5
# 4            1              8
# 5            4              9
# 6            1              7
# 7            3              7
# 8            1              1
# 9            3              5
# 10           4              1
# 11           5              1
# 12           5              5
# 13           4              5
# 14           4              7
# 15           2              9
# 16           3              4
# 17           3              7
# 18           5              9
# 19           4              6

# %%
df.iloc[0]         # First row (by position)
# Out:
# sale_id                   1
# product_id                3
# employee_id               2
# sale_date        2023-03-01
# quantity_sold             3
# total_price            1993
# Name: 0, dtype: object

# %%
df.loc[0]    # First row by label and index
# Out:
# sale_id                   1
# product_id                3
# employee_id               2
# sale_date        2023-03-01
# quantity_sold             3
# total_price            1993
# Name: 0, dtype: object

# %%
# 3. Filtering

df[df['quantity_sold'] > 5]
# Out:
#     sale_id  product_id  employee_id   sale_date  quantity_sold  total_price
# 1         2           4            2  2023-03-11              9          912
# 4         5           1            2  2023-04-10              8          490
# 5         6           4            3  2023-04-20              9          717
# 6         7           1            4  2023-04-30              7          903
# 7         8           3            4  2023-05-10              7         1094
# 14       15           4            2  2023-07-19              7         1074
# 15       16           2            2  2023-07-29              9          221
# 17       18           3            5  2023-08-18              7          644
# 18       19           5            5  2023-08-28              9          728
# 19       20           4            3  2023-09-07              6         1552

# %% [markdown]
# ## Data Cleaning with Pandas

# %% [markdown]
# ## Handling Missing Data

# %%
df.isnull().sum()              # Count missing
# Out:
# sale_id          0
# product_id       0
# employee_id      0
# sale_date        0
# quantity_sold    0
# total_price      0
# dtype: int64

# %%
df.fillna(0)                   # Fill with 0
# Out:
#     sale_id  product_id  employee_id   sale_date  quantity_sold  total_price
# 0         1           3            2  2023-03-01              3         1993
# 1         2           4            2  2023-03-11              9          912
# 2         3           4            3  2023-03-21              3          940
# 3         4           1            1  2023-03-31              5          963
# 4         5           1            2  2023-04-10              8          490
# 5         6           4            3  2023-04-20              9          717
# 6         7           1            4  2023-04-30              7          903
# 7         8           3            4  2023-05-10              7         1094
# 8         9           1            3  2023-05-20              1         1321
# 9        10           3            2  2023-05-30              5         1506
# 10       11           4            5  2023-06-09              1          332
# 11       12           5            5  2023-06-19              1          765
# 12       13           5            2  2023-06-29              5         1829
# 13       14           4            2  2023-07-09              5          417
# 14       15           4            2  2023-07-19              7         1074
# 15       16           2            2  2023-07-29              9          221
# 16       17           3            1  2023-08-08              4         1289
# 17       18           3            5  2023-08-18              7          644
# 18       19           5            5  2023-08-28              9          728
# 19       20           4            3  2023-09-07              6         1552

# %%
df.dropna()                    # Drop missing rows
# Out:
#     sale_id  product_id  employee_id   sale_date  quantity_sold  total_price
# 0         1           3            2  2023-03-01              3         1993
# 1         2           4            2  2023-03-11              9          912
# 2         3           4            3  2023-03-21              3          940
# 3         4           1            1  2023-03-31              5          963
# 4         5           1            2  2023-04-10              8          490
# 5         6           4            3  2023-04-20              9          717
# 6         7           1            4  2023-04-30              7          903
# 7         8           3            4  2023-05-10              7         1094
# 8         9           1            3  2023-05-20              1         1321
# 9        10           3            2  2023-05-30              5         1506
# 10       11           4            5  2023-06-09              1          332
# 11       12           5            5  2023-06-19              1          765
# 12       13           5            2  2023-06-29              5         1829
# 13       14           4            2  2023-07-09              5          417
# 14       15           4            2  2023-07-19              7         1074
# 15       16           2            2  2023-07-29              9          221
# 16       17           3            1  2023-08-08              4         1289
# 17       18           3            5  2023-08-18              7          644
# 18       19           5            5  2023-08-28              9          728
# 19       20           4            3  2023-09-07              6         1552

# %%
# renaming the Name column
df.rename(columns={'quantity_sold': 'number_of_quantity_sold'}, inplace=True)
df
# Out:
#     sale_id  product_id  employee_id   sale_date  number_of_quantity_sold  \
# 0         1           3            2  2023-03-01                        3
# 1         2           4            2  2023-03-11                        9
# 2         3           4            3  2023-03-21                        3
# 3         4           1            1  2023-03-31                        5
# 4         5           1            2  2023-04-10                        8
# 5         6           4            3  2023-04-20                        9
# 6         7           1            4  2023-04-30                        7
# 7         8           3            4  2023-05-10                        7
# 8         9           1            3  2023-05-20                        1
# 9        10           3            2  2023-05-30                        5
# 10       11           4            5  2023-06-09                        1
# 11       12           5            5  2023-06-19                        1
# 12       13           5            2  2023-06-29                        5
# 13       14           4            2  2023-07-09                        5
# 14       15           4            2  2023-07-19                        7
# 15       16           2            2  2023-07-29                        9
# 16       17           3            1  2023-08-08                        4
# 17       18           3            5  2023-08-18                        7
# 18       19           5            5  2023-08-28                        9
# 19       20           4            3  2023-09-07                        6
#
#     total_price
# 0          1993
# 1           912
# 2           940
# 3           963
# 4           490
# 5           717
# 6           903
# 7          1094
# 8          1321
# 9          1506
# 10          332
# 11          765
# 12         1829
# 13          417
# 14         1074
# 15          221
# 16         1289
# 17          644
# 18          728
# 19         1552

# %%
# 2. Renaming Columns

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['Lagos', 'Abuja', 'Ibadan']
}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age    City
# 0    Alice   25   Lagos
# 1      Bob   30   Abuja
# 2  Charlie   35  Ibadan

# %%
# renaming the Name column
df.rename(columns={'Name': 'FullName'}, inplace=True)

# Printing the updated DataFrame
print(df)
# Out:
#   FullName  Age    City
# 0    Alice   25   Lagos
# 1      Bob   30   Abuja
# 2  Charlie   35  Ibadan

# %%
# 3. Changing Data Types

df['Age'] = df['Age'].astype(float)

# %% [markdown]
# ## DataFrame Operations

# %%
# 1. Adding New Columns

df['Salary'] = [5000, 6000, 7000]

# %%
# 2. Applying Functions

df['AgePlusTen'] = df['Age'].apply(lambda x: x + 10)

# %%
# 3. Sorting

df.sort_values('Age', ascending=False)
# Out:
#   FullName   Age    City  Salary  AgePlusTen
# 2  Charlie  35.0  Ibadan    7000        45.0
# 1      Bob  30.0   Abuja    6000        40.0
# 0    Alice  25.0   Lagos    5000        35.0

# %% [markdown]
# ## Combining DataFrames

# %%
# 1. Concatenation

# First DataFrame
df1 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35]
})

# Second DataFrame
df2 = pd.DataFrame({
    'ID': [4, 5, 6],
    'Name': ['David', 'Emma', 'Frank'],
    'Age': [28, 32, 29]
})

# Joining them together - Concatenation
pd.concat([df1, df2])
# Out:
#    ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   3  Charlie   35
# 0   4    David   28
# 1   5     Emma   32
# 2   6    Frank   29

# %%
# For merge to work, we need matching IDs.

# Use this instead:

# New DataFrame for merging

df3 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Department': ['Sales', 'IT', 'Finance']
})

df3
# Out:
#    ID Department
# 0   1      Sales
# 1   2         IT
# 2   3    Finance

# %%
# 2. Merging (like SQL join)

pd.merge(df1, df3, on='ID', how='inner')
# Out:
#    ID     Name  Age Department
# 0   1    Alice   25      Sales
# 1   2      Bob   30         IT
# 2   3  Charlie   35    Finance

# %%
# 3. Joining

df1.join(df2, how='outer')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[304], line 3
#       1 # 3. Joining
# ----> 3 df1.join(df2, how='outer')
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:10764, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10754     if how == "cross":
#   10755         return merge(
#   10756             self,
#   10757             other,
#    (...)  10762             validate=validate,
#   10763         )
# > 10764     return merge(
#   10765         self,
#   10766         other,
#   10767         left_on=on,
#   10768         how=how,
#   10769         left_index=on is None,
#   10770         right_index=True,
#   10771         suffixes=(lsuffix, rsuffix),
#   10772         sort=sort,
#   10773         validate=validate,
#   10774     )
#   10775 else:
#   10776     if on is not None:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)    182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:840, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     837 left = self.left[:]
#     838 right = self.right[:]
# --> 840 llabels, rlabels = _items_overlap_with_suffix(
#     841     self.left._info_axis, self.right._info_axis, self.suffixes
#     842 )
#     844 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#     845     # Pinning the index here (and in the right code just below) is not
#     846     #  necessary, but makes the `.take` more performant if we have e.g.
#     847     #  a MultiIndex for left.index.
#     848     lmgr = left._mgr.reindex_indexer(
#     849         join_index,
#     850         left_indexer,
#    (...)    855         use_na_proxy=True,
#     856     )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:2721, in _items_overlap_with_suffix(left, right, suffixes)
#    2718 lsuffix, rsuffix = suffixes
#    2720 if not lsuffix and not rsuffix:
# -> 2721     raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2723 def renamer(x, suffix: str | None):
#    2724     """
#    2725     Rename the left and right indices.
#    2726
#    (...)   2737     x : renamed column name
#    2738     """
#
# ValueError: columns overlap but no suffix specified: Index(['ID', 'Name', 'Age'], dtype='object')

# %% [markdown]
# ## GroupBy and Aggregations

# %%
df.groupby('City')['Age'].mean()
# Out:
# City
# Abuja     30.0
# Ibadan    35.0
# Lagos     25.0
# Name: Age, dtype: float64

# %% [markdown]
# Common aggregation functions:
#
# - sum()
#
# - mean()
#
# - count()
#
# - min()
#
# - max()

# %% [markdown]
# ## Pivot Tables

# %%
df.pivot_table(index='City', columns='Gender', values='Salary', aggfunc='mean')

# %% [markdown]
# ## Reshaping and Melting

# %%
# Reshape:

df.pivot(index='Name', columns='City', values='Salary')

# %%
# Melt:

pd.melt(df, id_vars=['Name'], value_vars=['Salary', 'Age'])

# %% [markdown]
# ## Read:
#
# **pd.read_csv()**
#
# **pd.read_excel()**
#
# **pd.read_json()**

# %% [markdown]
# ## Write:
#
# **df.to_csv('filename.csv')**
#
# **df.to_excel('filename.xlsx')**
